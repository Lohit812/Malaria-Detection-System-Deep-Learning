# %%
import pandas as pd
import numpy as np
import os
import tensorflow
from tensorflow.keras.applications import ResNet50

# %%
train = '/content/drive/MyDrive/cell_images/cell_images/train'
test = '/content/drive/MyDrive/cell_images/cell_images/test'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255)
test_datagen=ImageDataGenerator(rescale=1./255)

training_set=train_datagen.flow_from_directory(train,target_size=(130,130),batch_size=32,class_mode='binary')
testing_set=test_datagen.flow_from_directory(test,target_size=(130,130),batch_size=12,class_mode='binary')
# Out:
# Found 34902 images belonging to 2 classes.
# Found 2600 images belonging to 2 classes.

# %%
basic_vgg = ResNet50(input_shape=(130,130,3),
                 include_top=False,
                 weights='imagenet')
# Out:
# ...
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten,Dropout

# %%
x=Flatten()(basic_vgg.output)
x=Dense(512,activation='relu')(x)
x=Dropout(0.2)(x)
x=Dense(1,activation='sigmoid')(x)

# %%
model=tensorflow.keras.Model(basic_vgg.input,x)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 130, 130, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 136, 136, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 65, 65, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 65, 65, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 65, 65, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 67, 67, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 33, 33, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 33, 33, 64)   4160        ['pool1_pool[0][0]']
#
# ...

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
hist=model.fit(x=training_set,steps_per_epoch=10,epochs=10)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 167s 11s/step - loss: 7.9091 - accuracy: 0.7094
# Epoch 2/10
# 10/10 [==============================] - 109s 10s/step - loss: 0.4603 - accuracy: 0.8313
# Epoch 3/10
# 10/10 [==============================] - 111s 10s/step - loss: 5.8210 - accuracy: 0.7469
# Epoch 4/10
# 10/10 [==============================] - 110s 10s/step - loss: 1.9837 - accuracy: 0.7344
# Epoch 5/10
# 10/10 [==============================] - 111s 10s/step - loss: 0.7531 - accuracy: 0.6938
# Epoch 6/10
# 10/10 [==============================] - 112s 10s/step - loss: 0.9330 - accuracy: 0.6812
# Epoch 7/10
# 10/10 [==============================] - 107s 10s/step - loss: 1.0894 - accuracy: 0.7594
# Epoch 8/10
# 10/10 [==============================] - 110s 10s/step - loss: 0.4717 - accuracy: 0.8562
# Epoch 9/10
# 10/10 [==============================] - 108s 10s/step - loss: 0.3771 - accuracy: 0.8969
# Epoch 10/10
# ...

# %%
print(model.evaluate(x=testing_set))
# Out:
# 217/217 [==============================] - 587s 3s/step - loss: 0.6973 - accuracy: 0.5000
# [0.6973095536231995, 0.5]
